# %%
from autoscraper import AutoScraper

# %%
scraper = AutoScraper()

# %%
# !ls
# Out:
# AutoScaper_Reload.ipynb     github_html.html
# First Web Auto Scrap.ipynb  github_htmlfile.html
# Web_Scrapping_Python.pptx   github_info
# amazon_iphone.ipynb         github_scrapping.ipynb
# amazon_watch                github_scrapping_File.ipynb
# amz_iPone_info              html_content

# %%
github_url = "https://github.com/binodsuman?tab=repositories";
candidate_list = ["14","Keras_Deep_Learning"]

# %%
scraper = AutoScraper()
result = scraper.build(url=github_url, wanted_list=candidate_list)
print(result)
# Out:
# ['1', '4', '11', '2', '3', '2,080', '1,103', '6', '14', '5', 'Java_AirQuality', 'Jaeger', 'kafka-spark-streaming-integration', 'kafka-spark-integration', 'Kafka_Flink_Integration', 'spring_youtube', 'spring', 'Java', 'azure_ml', 'MachineLearningNotebooks', 'ml-basics', 'SpringBoot_VisualStudioCode', 'Spark_ML', 'Spark', 'cerberus', 'AWS', 'dataset', 'deep-learning', 'kafka_python', 'Keras_Deep_Learning', 'rasa_chatbot', 'mapreduce_python', 'KMeans_Java', 'hadoop', 'tensorflow', 'mongodb', 'nlp', 'Spring_ConfigurationProperties', 'Spring_Boot_Data_JPA-', 'timeseries_ml_python']

# %%
html_content_locally = scraper._fetch_html(github_url)
html_content_locally
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" >\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-sD8zc/Dn1lguLc4FdbeVhD2gfxFCTXGr/y+MpJG3oX1vkAyaFf/7BHPtvv1dAHA0KG4bDEW3Ex1EPrzGTMtN2Q==" rel="stylesheet" href="https://github.githubassets.com/assets/light-b03f3373f0e7.css" /><link crossorigin="anonymous" media="all" integrity="sha512-V0872pNNqPTaPQFzdwX9tHIzJvB4F1Foi6VYDciZAMo/qHgBC8PvN2d/SkMweiNDbR6eF3cXcG0aPVrEtC8zqw==" rel="st
# ...

# %%
scraper = AutoScraper()
result = scraper.build(wanted_list=candidate_list,html=html_content_locally)
print(result)
# Out:
# ['1', '4', '11', '2', '3', '2,080', '1,103', '6', '14', '5', 'Java_AirQuality', 'Jaeger', 'kafka-spark-streaming-integration', 'kafka-spark-integration', 'Kafka_Flink_Integration', 'spring_youtube', 'spring', 'Java', 'azure_ml', 'MachineLearningNotebooks', 'ml-basics', 'SpringBoot_VisualStudioCode', 'Spark_ML', 'Spark', 'cerberus', 'AWS', 'dataset', 'deep-learning', 'kafka_python', 'Keras_Deep_Learning', 'rasa_chatbot', 'mapreduce_python', 'KMeans_Java', 'hadoop', 'tensorflow', 'mongodb', 'nlp', 'Spring_ConfigurationProperties', 'Spring_Boot_Data_JPA-', 'timeseries_ml_python']

# %%
file = open("html_content", mode='r')
content = file.read()
content
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" >\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-sD8zc/Dn1lguLc4FdbeVhD2gfxFCTXGr/y+MpJG3oX1vkAyaFf/7BHPtvv1dAHA0KG4bDEW3Ex1EPrzGTMtN2Q==" rel="stylesheet" href="https://github.githubassets.com/assets/light-b03f3373f0e7.css" /><link crossorigin="anonymous" media="all" integrity="sha512-V0872pNNqPTaPQFzdwX9tHIzJvB4F1Foi6VYDciZAMo/qHgBC8PvN2d/SkMweiNDbR6eF3cXcG0aPVrEtC8zqw==" rel="st
# ...

# %%
scraper = AutoScraper()
result = scraper.build(wanted_list=candidate_list,html=content)
print(result)
# Out:
# ['1', '4', '11', '2', '3', '2,079', '1,099', '6', '14', '5', 'Java_AirQuality', 'Jaeger', 'kafka-spark-streaming-integration', 'kafka-spark-integration', 'Kafka_Flink_Integration', 'spring_youtube', 'spring', 'Java', 'azure_ml', 'MachineLearningNotebooks', 'ml-basics', 'SpringBoot_VisualStudioCode', 'Spark_ML', 'Spark', 'cerberus', 'AWS', 'dataset', 'deep-learning', 'kafka_python', 'Keras_Deep_Learning', 'rasa_chatbot', 'mapreduce_python', 'KMeans_Java', 'hadoop', 'tensorflow', 'mongodb', 'nlp', 'Spring_ConfigurationProperties', 'Spring_Boot_Data_JPA-', 'timeseries_ml_python']

# %%
scraper = AutoScraper()
result = scraper.build(wanted_list=candidate_list,html=html_content)
print(result)

# %%
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" >\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-sD8zc/Dn1lguLc4FdbeVhD2gfxFCTXGr/y+MpJG3oX1vkAyaFf/7BHPtvv1dAHA0KG4bDEW3Ex1EPrzGTMtN2Q==" rel="stylesheet" href="https://github.githubassets.com/assets/light-b03f3373f0e7.css" /><link crossorigin="anonymous" media="all" integrity="sha512-V0872pNNqPTaPQFzdwX9tHIzJvB4F1Foi6VYDciZAMo/qHgBC8PvN2d/SkMweiNDbR6eF3cXcG0aPVrEtC8zqw==" rel="st
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(open("github_htmlfile.html"), "html.parser")
soup
# Out:
# '\n\n<!DOCTYPE html>
# ...

# %%
scraper = AutoScraper()
result = scraper.build(wanted_list=candidate_list,html=soup)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a88f8f3991f6> in <module>
#       1 scraper = AutoScraper()
# ----> 2 result = scraper.build(wanted_list=candidate_list,html=soup)
#       3 print(result)
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/autoscraper/auto_scraper.py in build(self, url, wanted_list, wanted_dict, html, request_args, update, text_fuzz_ratio)
#     225         """
#     226
# --> 227         soup = self._get_soup(url=url, html=html, request_args=request_args)
#     228
#     229         result_list = []
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/autoscraper/auto_scraper.py in _get_soup(cls, url, html, request_args)
#     115         if html:
#     116             html = normalize(unescape(html))
# --> 117             return BeautifulSoup(html, "lxml")
#     118
# ...

# %%
url = 'https://www.analyticsvidhya.com/blog/category/machine-learning/'
wanted_list = ['A Basic Introduction to Tensorflow in Deep Learning']

# %%
scraper = AutoScraper()
result = scraper.build(url, wanted_list)
print(result)
# Out:
# ['Multiple Linear Regression using Python', 'End-to-End Hotel Booking Cancellation Machine Learning Model', 'Introductory Guide on the Activation Functions', 'X-Ray Classification Using Pretrained-Stacked Model', 'A Basic Introduction to Tensorflow in Deep Learning', 'Gaussian Naive Bayes Algorithm for Credit Risk Modelling', 'Decoding Logistic Regression Using MLE', 'Restaurant Reviews Analysis Model Based on ML Algorithms', 'Introduction to Collaborative Filtering', 'Deep Learning vs Machine Learning for Regression']

# %%
url = "https://www.kaggle.com/competitions?hostSegmentIdFilter=11";
c_list = ["NFL Big Data Bowl 2022"]

# %%
scraper = AutoScraper()
result = scraper.build(url, c_list)
print(result)
# Out:
# []

# %%
youtube_url = "https://www.analyticsvidhya.com/blog/category/machine-learning/"
candiate_list = ["X-Ray Classification Using Pretrained-Stacked Model"]

# %%
result = scraper.build(youtube_url,candidate_list)
result
# Out:
# []

# %%
github_url = "https://github.com/binodsuman?tab=repositories";
candidate_list = ["14","Keras_Deep_Learning"]

# %%
result = scraper.build(github_url,candidate_list)
result
# Out:
# ['1',
#  '4',
#  '11',
#  '2',
#  '3',
#  '2,079',
#  '1,100',
#  '6',
#  '14',
#  '5',
#  'Java_AirQuality',
#  'Jaeger',
#  'kafka-spark-streaming-integration',
#  'kafka-spark-integration',
#  'Kafka_Flink_Integration',
#  'spring_youtube',
#  'spring',
#  'Java',
#  'azure_ml',
#  'MachineLearningNotebooks',
#  'ml-basics',
#  'SpringBoot_VisualStudioCode',
#  'Spark_ML',
#  'Spark',
#  'cerberus',
#  'AWS',
#  'dataset',
#  'deep-learning',
#  'kafka_python',
#  'Keras_Deep_Learning',
#  'rasa_chatbot',
#  'mapreduce_python',
#  'KMeans_Java',
#  'hadoop',
#  'tensorflow',
#  'mongodb',
#  'nlp',
#  'Spring_ConfigurationProperties',
#  'Spring_Boot_Data_JPA-',
#  'timeseries_ml_python']

# %%
github_url = "github_html.html";
candidate_list = ["14","Keras_Deep_Learning"]

# %%
result = scraper.build(github_url,candidate_list)
result
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-84-5119d2c18ddf> in <module>
# ----> 1 result = scraper.build(github_url,candidate_list)
#       2 result
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/autoscraper/auto_scraper.py in build(self, url, wanted_list, wanted_dict, html, request_args, update, text_fuzz_ratio)
#     225         """
#     226
# --> 227         soup = self._get_soup(url=url, html=html, request_args=request_args)
#     228
#     229         result_list = []
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/autoscraper/auto_scraper.py in _get_soup(cls, url, html, request_args)
#     117             return BeautifulSoup(html, "lxml")
#     118
# --> 119         html = cls._fetch_html(url, request_args)
#     120         html = normalize(unescape(html))
#     121
#
# ...

# %%
scraper.get_result_similar(github_url,grouped=True)
# Out:
# {'rule_5x72': ['1',
#   '4',
#   '11',
#   '2',
#   '1',
#   '3',
#   '2,078',
#   '1,097',
#   '1',
#   '3',
#   '6',
#   '3',
#   '2',
#   '3',
#   '14',
#   '5',
#   '1',
#   '1',
#   '1',
#   '4',
#   '1'],
#  'rule_6lpx': ['Java_AirQuality',
#   'Jaeger',
#   'kafka-spark-streaming-integration',
#   'kafka-spark-integration',
#   'Kafka_Flink_Integration',
#   'spring_youtube',
#   'spring',
#   'Java',
#   'azure_ml',
#   'MachineLearningNotebooks',
#   'ml-basics',
#   'SpringBoot_VisualStudioCode',
#   'Spark_ML',
#   'Spark',
#   'cerberus',
#   'AWS',
#   'dataset',
#   'deep-learning',
#   'kafka_python',
#   'Keras_Deep_Learning',
#   'rasa_chatbot',
#   'mapreduce_python',
#   'KMeans_Java',
#   'hadoop',
#   'tensorflow',
#   'mongodb',
#   'nlp',
#   'Spring_ConfigurationProperties',
#   'Spring_Boot_Data_JPA-',
#   'timeseries_ml_python']}

# %%
scraper.set_rule_aliases({'rule_5x72':'Stars','rule_6lpx':'Title'})
scraper.keep_rules(['rule_5x72','rule_6lpx'])
scraper.save('github_info')

# %%
scraper.load('github_info')

# %%
scraper.load('github_info')

# %%
result = scraper.get_result_similar("https://github.com/sureshvis?tab=repositories",group_by_alias=True)
result
# Out:
# {'Stars': ['364', '425', '1,224', '10,616', '31,649', '6,082'],
#  'Title': ['community',
#   'api',
#   'istio.io',
#   'test-',
#   'kubernetes.github.io',
#   'kubernetes',
#   'helm',
#   'Misc']}

# %%
result['Stars']
# Out:
# ['8', '213', '1', '5', '4', '2', '2']

# %%
result['Title']
# Out:
# ['Deep-Learning-Projects',
#  'Machine-Learning-Projects',
#  'Reinforcement-Learning-Projects',
#  'python-tutorial',
#  'Python-Projects',
#  'Blockchain-Projects',
#  'Data-Structures-and-Algorithms-Notes',
#  'Web-Scraping']

# %%
result = scraper.get_result_similar("https://github.com/lukeyuan31?tab=repositories",group_by_alias=True)
result
# Out:
# {'Stars': ['1', '1', '1', '1', '2', '1', '64', '27'],
#  'Title': ['MarketDataAnalysis',
#   'Churn_Visulization',
#   'MovieDataAnalysis',
#   'dota2_watcher',
#   'MachineLearning',
#   'AOAProject',
#   'my-rpc',
#   'LeetCode-Notes',
#   'SoftwareEngineeringPics',
#   'DOSP-Projects',
#   'P2PFileSystem',
#   'ADSProject',
#   'STGame',
#   'TCPServerClient',
#   'learngit',
#   'testTravis.ci',
#   'InfluenceMaximization',
#   'ObjectOrientedDesign',
#   'influence-maximization',
#   'webAppsAssignments']}

# %%
len(result['Title'])
# Out:
# 20

# %%
result = scraper.get_result_similar("https://github.com/binodsuman?tab=repositories",group_by_alias=True)
len(result['Title'])
# Out:
# 30

# %%
result = scraper.get_result_similar("https://github.com/binodsuman?after=Y3Vyc29yOnYyOpK0MjAxOS0xMC0wNVQxODo1NjoyNVrODLLxLQ%3D%3D&tab=repositories",group_by_alias=True)
len(result['Title'])
# Out:
# 14
